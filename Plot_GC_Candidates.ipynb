# %% [markdown]
# <a href="https://colab.research.google.com/github/EduGod0y/astrophysics/blob/main/Plot_GC_Candidates.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#@title Imports
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from astropy.wcs import WCS
from astropy.io import fits
from astropy.utils.data import get_pkg_data_filename
import matplotlib.pyplot as plt
from astropy.table import Table
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data = Table.read('/content/J-PLUS-Forbes-NGC2403.fits')
RA = data['ALPHA_J2000']
DEC = data['DELTA_J2000']
c = data['gAP3']

# %%
name = 'image_r_ngc2403.fz'
image_file = get_pkg_data_filename(name)
hdu = fits.open(image_file)[1]
wcs = WCS(hdu.header)
# Out:
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set DATE-OBS to '2019-03-11' from MJD-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set DATE-OBS to '2019-03-11' from MJD-OBS'.

# %%
fig = plt.figure(figsize=(14,14))
ax = fig.add_subplot(1,1,1)
ax = plt.subplot(projection=wcs)
j = ax.scatter(RA, DEC,  marker='.',c=c, s=300, alpha=1,lw=3, facecolors='none', transform=ax.get_transform('world'))
j.set_facecolor('none')


plt.rc('axes', labelsize=15) 
# set the color limits
#im.set_clim(0.8, 1.0)
title = 'NGC 4244'
#ax.legend()

plt.rc('axes', labelsize=40)
plt.rc('lines', lw=2.0,color='k')
plt.rc('axes',lw=2.0)
plt.rc('legend', fontsize=30)
fig.colorbar(j, ax=ax, label='G[mag]',)


plt.rc('xtick', labelsize=30) 
plt.rc('ytick', labelsize=30)
ax.set_xlabel('RA', size=36)
ax.set_ylabel('DEC', size=36)
plt.title(title, size=28)
plt.tight_layout()

ax.imshow(hdu.data, cmap='gist_yarg', vmin=-9.4, vmax=24) 
#ax.imshow(hdu.data, vmin=-9.4, vmax=24) 
plt.tight_layout()
plt.show()
